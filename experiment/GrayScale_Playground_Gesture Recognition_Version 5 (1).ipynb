# %% [markdown]
# # "Smart" Gesture Recognition
#
#
# **Business Proposal**
#
# Nowadays, technology has a pivotal role in creating virtual environments with virtual elements. We work collaboratively with real-world intelligent objects on a day-to-day basis. Innovations like the Internet of things (IoT) products, gesture recognition, and teleportation application have certainly made our life "smarter" and more accessible.
#
#
# Embracing an "implementing a smarter life" mindset, Team College aims to develop a cool feature in the smart TV that can recognize five different gestures performed by the user to help users control the TV without using a remote. Based on this dataset, Team College wants to develop a well-rounded deep learning gesture recognition model which has applications in a spectrum of different industries beyond smart-TV.
#
# **Dataset Description**
# The data consists of a few hundred videos categorized into five classes: thumb up, thumb down, swipe left, swipe right, stop. The webcam mounted on the TV continuously monitors the gestures. Each motion corresponds to a specific command:
#
# | Gesture | Corresponding Action |
# | --- | --- |
# | Thumbs Up | Increase the volume. |
# | Thumbs Down | Decrease the volume. |
# | Left Swipe | 'Jump' backwards 10 seconds. |
# | Right Swipe | 'Jump' forward 10 seconds. |
# | Stop | Pause the movie. |
#
# The training data consists of 19,890 images (663*30): there are 663 videos categorized into one of the five classes. Each video (typically 2-3 seconds long) is divided into a sequence of 30 frames(images). The testing data consists of a total of 3,000 images.
#
# Various people have recorded these videos performing one of the five gestures in front of a webcam - like what the smart TV will use. Specifically, videos have two types of dimensions - either 360x360 or 120x160 (depending on the webcam used to record the videos)
#
# ### Team College Objectives:
# 1. **Data Preprocessing_Generator Establishment**:  Team College aim to build a function called "Generator" so that this fuction should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# 2. **Experimentation _ Model Architecture**: Team College aim to develop the best model that is able to train with high accuracy and without any errors. To achieve the goal, Conv3D with Maxpolling 3D, RNN, CNN LSTM with GRU (for augmentation) models will be used to tackle the problem.
#
# 3. **Best Performing Model**: Further Development and Tryouts such as Generative Adversarial Networks (GAN) , Different Batch Size, Learning Rate and tansfer learning method will be applied to design the best performing Model.

# %% [markdown]
# ## Housekeeping Setup

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Activation, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.utils import np_utils
from tensorflow.keras.utils import to_categorical
from matplotlib import image

import os
from skimage.transform import resize
from imageio import imread
import datetime

import pathlib
from os.path import isfile, join

import matplotlib.pyplot as plt
import PIL
import PIL.Image
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We set the random seed as 30 to ensure the steady outcome

# %%
import datetime
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(30)

import torch
import torch.nn as nn

# %% [markdown]
# Setp for GPU check, if you have it, lucky you; ifelse, this might take some time to compute :)

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# ## Load Data - Colorful Image
#
# - No. training sequences = 530
# - No. validation sequences = 133
# - No. testing sequences = 100
#
# train-val-test = 70% - 17% -13%

# %%
train_doc = np.random.permutation(open('Project_data/train.csv').readlines())
test_doc = np.random.permutation(open('Project_data/test.csv').readlines())
val_doc = np.random.permutation(open('Project_data/val.csv').readlines())
batch_size = 64

# %% [markdown]
# ## Data EDA
# Sample train and val dataset display as follow:
# - train_doc contains 662 datapoints
# - val-doc contains 100 datapoints

# %%
train_doc
# Out:
# array(['WIN_20180926_17_13_13_Pro_Right_Swipe_new,Right_Swipe_new,1\n',
#        'WIN_20180925_18_08_08_Pro_Thumbs_Up_new,Thumbs_Up_new,4\n',
#        'WIN_20180907_16_12_09_Pro_Stop Gesture_new,Stop Gesture_new,2\n',
#        'WIN_20180926_17_23_39_Pro_Left_Swipe_new,Left_Swipe_new,0\n',
#        'WIN_20180926_17_12_26_Pro_Stop_new,Stop_new,2\n',
#        'WIN_20180926_17_08_38_Pro_Thumbs_Down_new,Thumbs_Down_new,3\n',
#        'WIN_20180926_17_22_16_Pro_Thumbs_Up_new,Thumbs_Up_new,4\n',
#        'WIN_20180925_18_14_35_Pro_Right_Swipe_new,Right_Swipe_new,1\n',
#        'WIN_20180925_17_57_36_Pro_Left_Swipe_new,Left_Swipe_new,0\n',
#        'WIN_20180926_17_05_32_Pro_Stop_new,Stop_new,2\n',
#        'WIN_20180907_16_25_10_Pro_Thumbs Up_new,Thumbs Up_new,4\n',
#        'WIN_20180926_17_47_31_Pro_Thumbs_Down_new,Thumbs_Down_new,3\n',
#        'WIN_20180925_17_42_12_Pro_Right_Swipe_new,Right_Swipe_new,1\n',
#        'WIN_20180925_17_46_33_Pro_Thumbs_Down_new,Thumbs_Down_new,3\n',
#        'WIN_20180926_17_24_33_Pro_Thumbs_Up_new,Thumbs_Up_new,4\n',
#        'WIN_20180926_17_28_47_Pro_Left_Swipe_new,Left_Swipe_new,0\n',
#        'WIN_20180926_17_22_54_Pro_Left_Swipe_new,Left_Swipe_new,0\n',
#        'WIN_20180926_17_10_46_Pro_Stop_new,Stop_new,2\n',
#        'WIN_20180926_17_07_50_Pro_Right_Swipe_new,Right_Swipe_new,1\n',
#        'WIN_20180926_17_06_24_Pro_Left_Swipe_new,Left_Swipe_new,0\n',
#        'WIN_20180926_16_52_43_Pro_Thumbs_Down_new,Thumbs_Down_new,3\n',
#        'WIN_20180925_17_35_12_Pro_Stop_new,Stop_new,2\n',
#        'WIN_20180925_17_47_06_Pro_Thumbs_Down_new,Thumbs_Down_new,3\n',
#        'WIN_20180925_17_55_12_Pro_Left_Swipe_new,Left_Swipe_new,0\n',
#        'WIN_20180926_17_22_49_Pro_Right_Swipe_new,Right_Swipe_new,1\n',
#        'WIN_20180925_17_57_06_Pro_Thumbs_Down_new,Thumbs_Down_new,3\n',
#        'WIN_20180925_17_48
Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180926_16_44_04_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180925_17_40_03_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180925_17_43_46_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180925_17_43_01_Pro_Left_Swipe_new;Left_Swipe_new;0\n',
#        'WIN_20180907_15_55_06_Pro_Right Swipe_new;Right Swipe_new;1\n',
#        'WIN_20180926_17_32_15_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180926_17_33_14_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180925_17_47_07_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180925_17_49_40_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180907_16_02_38_Pro_Right Swipe_new;Right Swipe_new;1\n',
#        'WIN_20180907_16_16_48_Pro_Stop Gesture_new;Stop Gesture_new;2\n',
#        'WIN_20180907_16_13_24_Pro_Thumbs Down_new;Thumbs Down_new;3\n',
#        'WIN_20180925_17_38_43_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180925_17_59_48_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180907_16_09_35_Pro_Thumbs Down_new;Thumbs Down_new;3\n',
#        'WIN_20180907_16_25_57_Pro_Right Swipe_new;Right Swipe_new;1\n',
#        'WIN_20180926_17_24_12_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180907_16_17_35_Pro_Stop Gesture_new;Stop Gesture_new;2\n',
#        'WIN_20180926_17_05_38_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180926_17_32_40_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180926_16_48_48_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180907_15_47_33_Pro_Thumbs Down_new;Thumbs Down_new;3\n',
#        'WIN_20180926_17_06_40_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180925_17_25_06_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180926_16_48_40_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180907_16_00_42_Pro_Left Swipe_new_Left Swipe_new;Left Swipe_new_Left Swipe_new;0\n',
#        'WIN_20180926_17_04_53_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180926_17_08_11_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180925_17_17_04_Pro_Left_Swipe_new;Left_Swipe_new;0\n',
#        'WIN_20180926_17_14_26_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180925_17_42_34_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180907_16_31_41_Pro_Stop Gesture_new;Stop Gesture_new;2\n',
#        'WIN_20180926_17_24_20_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180925_17_50_24_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180926_17_28_32_Pro_Thumbs_Up_new;Thumbs_Up_new;4\n',
#        'WIN_20180926_17_44_14_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180926_16_37_56_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180907_16_07_10_Pro_Thumbs Down_new;Thumbs Down_new;3\n',
#        'WIN_20180926_17_12_27_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180925_17_32_32_Pro_Stop_new;Stop_new;2\n',
#        'WIN_20180907_16_30_54_Pro_Stop Gesture_new;Stop Gesture_new;2\n',
#        'WIN_20180907_16_20_15_Pro_Stop Gesture_new;Stop Gesture_new;2\n',
#        'WIN_20180907_15_45_04_Pro_Left Swipe_new_Left Swipe_new;Left Swipe_new_Left Swipe_new;0\n',
#        'WIN_20180907_16_25_44_Pro_Stop Gesture_new;Stop Gesture_new;2\n',
#        'WIN_20180926_17_13_25_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180907_16_21_39_Pro_Left Swipe_new_Left Swipe_new;Left Swipe_new_Left Swipe_new;0\n',
#        'WIN_20180925_17_35_29_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180925_17_33_30_Pro_Thumbs_Down_new;Thumbs_Down_new;3\n',
#        'WIN_20180926_17_34_05_Pro_Right_Swipe_new;Right_Swipe_new;1\n',
#        'WIN_20180907_16_05_10_Pro_Right Swipe_new;Right Swipe_new;1\n',
#        'WIN_20180907_15_50_39_Pro_Right Swipe_new;Right Swipe_new;1\n',
#        'WIN_20180907_16_05_32_Pro_Left Swipe_new_Left Swipe_new;Left Swipe_new_Left Swipe_new;0\n'],
#       dtype='<U88')

# %% [markdown]
# ## Data Preprocessing
# Following steps are followed:
# 1. Resized the image and cropped smaller image shape at center for 120*120
# 2. Normalized Images
# 3. Built 3D and 2D filter function
# 4. Established function to get batch data for preprocessing Convo3D

# %%
def cropResize(image, y, z):
    h, w = image.shape
    
    # if smaller image crop at center for 120x120
    if w == 160:
        image = image[:120, 20:140]

    # resize every image
    return resize(image, (y,z))

# %%
def normalizeImage(image):
    # applying normalization
    return image/255.0

# %%
def preprocessImage(image, y, z):
    return normalizeImage(cropResize(image, y, z))

# %%
def make3dFilter(x):
    return tuple([x]*3)

def make2dFilter(x):
    return tuple([x]*2)

# %% [markdown]
# ### For Windows User Only

# %%
def getBatchData(source_path, t, batch, batch_size, img_tensor):
    [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
    img_idx = img_tensor[0]
    batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    for folder in range(batch_size): # iterate over the batch_size
        imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
        for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
            image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes

            # separate preprocessImage function is defined for cropping, resizing and normalizing images
            batch_data[folder,idx,:,:,0] = preprocessImage(image[:, :, 0], y, z)
            batch_data[folder,idx,:,:,1] = preprocessImage(image[:, :, 1], y, z)
            batch_data[folder,idx,:,:,2] = preprocessImage(image[:, :, 2], y, z)

        batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
    return batch_data, batch_labels

# %% [markdown]
# ### For Mac User Only

# %%
def getBatchData(source_path, t, batch, batch_size, img_tensor):
    [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
    img_idx = img_tensor[0]
    batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    for folder in range(batch_size): # iterate over the batch_size
        imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(',')[0]) # read all the images in the folder
        for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
            image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(',')[0]+'/'+imgs[item]).astype(np.float32)

            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes

            # separate preprocessImage function is defined for cropping, resizing and normalizing images
            batch_data[folder,idx,:,:,0] = preprocessImage(image[:, :, 0], y, z)
            batch_data[folder,idx,:,:,1] = preprocessImage(image[:, :, 1], y, z)
            batch_data[folder,idx,:,:,2] = preprocessImage(image[:, :, 2], y, z)

        batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(',')[2])] = 1
    return batch_data, batch_labels

# %% [markdown]
# ## Generator Establishment
# Since the dataset contains 2 types of dimensions, a "generator" is build to preprocess the images for `2D` and `3D` dimensions, as well as create `a batch of video frames`. We experiment with `img_idx`, `y`,`z` and normalization such that to achieve a high accuracy outcome.

# %%
def generator(source_path, folder_list, batch_size, img_tensor):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list)/batch_size)
        for batch in range(num_batches): # we iterate over the number of batches
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)
        
        # write the code for the remaining data points which are left after full batches
        # checking if any remaining batches are there or not
        if len(folder_list)%batch_size != 0:
            # updated the batch size and yield
            batch_size = len(folder_list)%batch_size
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)

# %% [markdown]
# Note: a video is represented above in the generator as (number of images, height, width, number of channels)

# %%
curr_dt_time = datetime.datetime.now()
train_path = './Project_data/train'
val_path = './Project_data/val'
test_path = './Project_data/test'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_test_sequences = len(test_doc)
print('# Test sequences =', num_test_sequences)
num_epochs = 10
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 530
# # validation sequences = 133
# # Test sequences = 100
# # epochs = 10

# %%
def getImgTensor(n_frames):
    img_idx = np.round(np.linspace(0, 29, n_frames)).astype(int)
    return [img_idx, 100, 100, 3]

# define image tensor size
img_tensor = getImgTensor(20)
print ('# img_tensor =', img_tensor)
# Out:
# # img_tensor = [array([ 0,  2,  3,  5,  6,  8,  9, 11, 12, 14, 15, 17, 18, 20, 21, 23, 24,
#        26, 27, 29]), 100, 100, 3]

# %% [markdown]
# ### Generator Validation

# %%
# check complete batch shape
sample_generator = generator(train_path, train_doc, batch_size, img_tensor)
sample_batch_data, sample_batch_labels = next(sample_generator)
print(sample_batch_data.shape)

# validation batch sample
sample_val_generator = generator(val_path, val_doc, batch_size, img_tensor)
sample_val_batch_data, sample_val_batch_labels = next(sample_val_generator)
print(sample_val_batch_data.shape)
# Out:
# Source path =  ./Project_data/train ; batch size = 64
# (64, 20, 100, 100, 3)
# Source path =  ./Project_data/val ; batch size = 64
# (64, 20, 100, 100, 3)

# %%
# plot generated sample images
fig, ax = plt.subplots(1,2)
ax[0].imshow(sample_val_batch_data[15,10,:,:,:])   
ax[1].imshow(sample_val_batch_data[5,10,:,:,:])
plt.show()

# %%
def plotModelHistory(h):
    fig, ax = plt.subplots(1, 2, figsize=(15,4))
    ax[0].plot(h.history['loss'])   
    ax[0].plot(h.history['val_loss'])
    ax[0].legend(['loss','val_loss'])
    ax[0].title.set_text("Train loss vs Validation loss")

    ax[1].plot(h.history['categorical_accuracy'])   
    ax[1].plot(h.history['val_categorical_accuracy'])
    ax[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    ax[1].title.set_text("Train accuracy vs Validation accuracy")
    plt.show()

    print("Max. Training Accuracy", max(h.history['categorical_accuracy']))
    print("Max. Validaiton Accuracy", max(h.history['val_categorical_accuracy']))

# %% [markdown]
# ## Model Building
# Team College aim to develop the best model that is able to train with high accuracy and without any errors. To achieve the goal, following Models have been used for tryouts:
#
# 1. `Conv3D` with `MaxPooling3D` for a 3D convolution model
# 2. `TimeDistributed` while building a Conv2D + RNN model
# 3. `CNN LSTM with GRU` for augmentation
#
# Moreover, for each model, we set the last layer is the softmax so that the least number of parameters can fit in the memory of the webcam. Hence to perform a good accuracy on the least number of parameters.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau,CSVLogger,LearningRateScheduler
from keras import optimizers

# %% [markdown]
# ### Base Model

# %%
#write your model here
def defineModel(img_tensor):
    
    opt = tf.keras.optimizers.Adam()
    
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 16, 96, 96, 16)    6016
#
#  max_pooling3d (MaxPooling3D  (None, 8, 48, 48, 16)    0
#  )
#
#  batch_normalization (BatchN  (None, 8, 48, 48, 16)    64
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 6, 46, 46, 32)     13856
#
#  max_pooling3d_1 (MaxPooling  (None, 6, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 6, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 4, 21, 21, 64)     55360
#
#  max_pooling3d_2 (MaxPooling  (None, 4, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 4, 11, 11, 64)    256
#  hNormalization)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4,050,085
# Trainable params: 4,049,477
# Non-trainable params: 608
# _________________________________________________________________

# %%
#write your model here
def defineModel(img_tensor):
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])
    
    opt = tf.keras.optimizers.Adam()

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(opt, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 16, 96, 96, 16)    6016
#
#  max_pooling3d_3 (MaxPooling  (None, 8, 48, 48, 16)    0
#  3D)
#
#  batch_normalization_5 (Batc  (None, 8, 48, 48, 16)    64
#  hNormalization)
#
#  conv3d_4 (Conv3D)           (None, 6, 46, 46, 32)     13856
#
#  max_pooling3d_4 (MaxPooling  (None, 6, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_6 (Batc  (None, 6, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_5 (Conv3D)           (None, 4, 21, 21, 64)     55360
#
#  max_pooling3d_5 (MaxPooling  (None, 4, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_7 (Batc  (None, 4, 11, 11, 64)    256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_3 (Dense)             (None, 128)               3965056
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4,050,085
# Trainable params: 4,049,477
# Non-trainable params: 608
# _________________________________________________________________

# %%
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit_generator` to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# ### Model Callbacks Setup _ CheckPoint, Earlystop & Tensorboard Callbacks

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}.h5'


checkpoint = ModelCheckpoint(
    filepath,
    monitor='val_loss',
    verbose=1,
    save_best_only=True,
    save_weights_only=False,
    save_freq=1,
    mode='auto', 
    save_fre='epoch'
)
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    min_delta=0.001,
    patience=4,
    verbose=1,
    #min_delta=0,
    mode='auto'
)
tensorboard = tf.keras.callbacks.TensorBoard(
    log_dir = './logs',
    histogram_freq=0,
    batch_size=16,
    write_graph=True,
    write_grads=True,
    write_images=False,
    embeddings_freq=0
)

csvlogger = CSVLogger(
    filename= "training_csv.log",
    separator = ",",
    append = False
)

reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.1,
    patience=3,
    verbose=1, 
    mode='auto'
)

callbacks_list = [checkpoint,tensorboard,csvlogger,reduce]
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:`batch_size` is no longer needed in the `TensorBoard` Callback and will be ignored in TensorFlow 2.0.

# %% [markdown]
# ### Test Batch Size & Frames

# %%
def testBatchSize(batch_size, n_frames):
    img_tensor = getImgTensor(n_frames)
    print("Using frames as", img_tensor[0])
    global callbacks_list
    num_epochs = 3
    train_generator = generator(train_path, train_doc, batch_size, img_tensor)
    val_generator = generator(val_path, val_doc, batch_size, img_tensor)
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    model = defineModel(img_tensor)
    model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                callbacks=callbacks_list, validation_data=val_generator, 
                validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %%
#testBatchSize(batch_size=64, n_frames=30)

# %%
testBatchSize(batch_size=64, n_frames=16)
# Out:
# Using frames as [ 0  2  4  6  8 10 12 14 15 17 19 21 23 25 27 29]
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/3
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 2:43 - loss: 2.2167 - categorical_accuracy: 0.1875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2:17 - loss: 1.8806 - categorical_accuracy: 0.2969WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 1:56 - loss: 1.7016 - categorical_accuracy: 0.3646WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1:36 - loss: 1.6887 - categorical_accuracy: 0.3867WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1:16 - loss: 1.5944 - categorical_accuracy: 0.4156WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 57s - loss: 1.5799 - categorical_accuracy: 0.4115 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 38s - loss: 1.5218 - categorical_accuracy: 0.4308WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 19s - loss: 1.4703 - categorical_accuracy: 0.4473WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 1.4447 - categorical_accuracy: 0.4566 Source path =  ./Project_data/val ; batch size = 64
# 9/9 [==============================] - 179s 20s/step - loss: 1.4447 - categorical_accuracy: 0.4566 - val_loss: 4.9355 - val_categorical_accuracy: 0.2632 - lr: 0.0010
# Epoch 2/3
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 44s - loss: 0.9707 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 37s - loss: 0.8829 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 32s - loss: 0.8724 - categorical_accuracy: 0.6852WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 27s - loss: 0.9146 - categorical_accuracy: 0.6806WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 21s - loss: 0.8859 - categorical_accuracy: 0.6778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 16s - loss: 0.9744 - categorical_accuracy: 0.6481WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 10s - loss: 0.9411 - categorical_accuracy: 0.6587WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 5s - loss: 0.9381 - categorical_accuracy: 0.6528 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 51s 6s/step - loss: 0.9581 - categorical_accuracy: 0.6543 - val_loss: 2.1200 - val_categorical_accuracy: 0.1333 - lr: 0.0010
# Epoch 3/3
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 43s - loss: 1.1989 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 37s - loss: 0.9706 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 32s - loss: 0.9914 - categorical_accuracy: 0.6296WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 26s - loss: 1.0642 - categorical_accuracy: 0.5694WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 21s - loss: 1.0082 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 16s - loss: 1.0012 - categorical_accuracy: 0.6204WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 10s - loss: 0.9558 - categorical_accuracy: 0.6270WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 5s - loss: 0.8808 - categorical_accuracy: 0.6528 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 51s 6s/step - loss: 0.8777 - categorical_accuracy: 0.6605 - val_loss: 4.0538 - val_categorical_accuracy: 0.0667 - lr: 0.0010

# %%
#testBatchSize(batch_size=32, n_frames=30)

# %%
#testBatchSize(batch_size=32, n_frames=16)

# %% [markdown]
# With above observations, we can see that batch size is not impacting training time but number of frames. We will use **batch size of 64 and frame of 16** as it seems optimal. It is commented as it takes a lot of time to run that is restricting for the notebook to completely run.

# %% [markdown]
# ### Model 1.0 - Frames-16, Epoc-20, relu

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model1 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d1")
model1.compile(optimizer= tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())

model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_9 (Conv3D)           (None, 12, 96, 96, 16)    6016
#
#  max_pooling3d_9 (MaxPooling  (None, 6, 48, 48, 16)    0
#  3D)
#
#  batch_normalization_15 (Bat  (None, 6, 48, 48, 16)    64
#  chNormalization)
#
#  conv3d_10 (Conv3D)          (None, 4, 46, 46, 32)     13856
#
#  max_pooling3d_10 (MaxPoolin  (None, 4, 23, 23, 32)    0
#  g3D)
#
#  batch_normalization_16 (Bat  (None, 4, 23, 23, 32)    128
#  chNormalization)
#
#  conv3d_11 (Conv3D)          (None, 2, 21, 21, 64)     55360
#
#  max_pooling3d_11 (MaxPoolin  (None, 2, 11, 11, 64)    0
#  g3D)
#
#  batch_normalization_17 (Bat  (None, 2, 11, 11, 64)    256
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 15488)             0
#
#  dense_9 (Dense)             (None, 128)               1982592
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  batch_normalization_19 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 2,067,621
# Trainable params: 2,067,013
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 2:41 - loss: 2.4232 - categorical_accuracy: 0.2031WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2:14 - loss: 2.1638 - categorical_accuracy: 0.2734WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 1:54 - loss: 1.8992 - categorical_accuracy: 0.3333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1:35 - loss: 1.8368 - categorical_accuracy: 0.3359WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1:16 - loss: 1.7502 - categorical_accuracy: 0.3594WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 57s - loss: 1.6756 - categorical_accuracy: 0.3750 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 38s - loss: 1.6081 - categorical_accuracy: 0.4018WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 18s - loss: 1.5560 - categorical_accuracy: 0.4141WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 1.5259 - categorical_accuracy: 0.4264 Source path =  ./Project_data/val ; batch size = 64
# 9/9 [==============================] - 177s 20s/step - loss: 1.5259 - categorical_accuracy: 0.4264 - val_loss: 3.3504 - val_categorical_accuracy: 0.2406 - lr: 0.0010
# Epoch 2/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 42s - loss: 1.0795 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 37s - loss: 0.8119 - categorical_accuracy: 0.6944WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 32s - loss: 0.7507 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 26s - loss: 0.7469 - categorical_accuracy: 0.7361WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 21s - loss: 0.8443 - categorical_accuracy: 0.6889WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 16s - loss: 0.8618 - categorical_accuracy: 0.6759WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 11s - loss: 0.8461 - categorical_accuracy: 0.6746WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 5s - loss: 0.8740 - categorical_accuracy: 0.6528 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 52s 6s/step - loss: 0.8768 - categorical_accuracy: 0.6605 - val_loss: 4.0457 - val_categorical_accuracy: 0.2667 - lr: 0.0010
# Epoch 3/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 43s - loss: 0.7934 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 37s - loss: 0.9689 - categorical_accuracy: 0.6944WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 32s - loss: 0.9893 - categorical_accuracy: 0.6481WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 26s - loss: 1.0341 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 21s - loss: 0.9494 - categorical_accuracy: 0.6222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 16s - loss: 1.0432 - categorical_accuracy: 0.6204WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 10s - loss: 1.0525 - categorical_accuracy: 0.6270WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 5s - loss:
- categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.5318 - categorical_accuracy: 0.5625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 909ms/step - loss: 1.4853 - categorical_accuracy: 0.5556 - val_loss: 1.3795 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 14/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 0.9715 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 4s - loss: 2.2477 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 2.7004 - categorical_accuracy: 0.1667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 2.7257 - categorical_accuracy: 0.1250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 2.3886 - categorical_accuracy: 0.2000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 2.2740 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 2.0668 - categorical_accuracy: 0.2857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 2.2709 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 920ms/step - loss: 2.1567 - categorical_accuracy: 0.2778 - val_loss: 1.8131 - val_categorical_accuracy: 0.4444 - lr: 1.0000e-04
# Epoch 15/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 3.1386 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 3.2662 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 2.3099 - categorical_accuracy: 0.3333    WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 2.5085 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 2.1166 - categorical_accuracy: 0.3000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 1.9894 - categorical_accuracy: 0.3333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.8300 - categorical_accuracy: 0.3571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.6117 - categorical_accuracy: 0.4375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 1.5651 - categorical_accuracy: 0.3889
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 9/9 [==============================] - 8s 906ms/step - loss: 1.5651 - categorical_accuracy: 0.3889 - val_loss: 1.7195 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-04
# Epoch 16/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 2.5211 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 2.3010 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 1.6812 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 1.8513 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 1.5617 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 1.3875 - categorical_accuracy: 0.5833WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.4123 - categorical_accuracy: 0.5714WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.5946 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 891ms/step - loss: 1.6528 - categorical_accuracy: 0.4444 - val_loss: 1.9589 - val_categorical_accuracy: 0.2222 - lr: 1.0000e-05
# Epoch 17/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 0.9020 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 2.0675 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 2.2133 - categorical_accuracy: 0.1667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 2.1529 - categorical_accuracy: 0.1250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 2.3969 - categorical_accuracy: 0.2000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 2.0748 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.9442 - categorical_accuracy: 0.2857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.9448 - categorical_accuracy: 0.3125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 923ms/step - loss: 2.1151 - categorical_accuracy: 0.2778 - val_loss: 2.8988 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-05
# Epoch 18/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 1.6232 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 1.2576 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 1.2168 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 1.6162 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 1.8463 - categorical_accuracy: 0.4000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 1.6327 - categorical_accuracy: 0.4167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.7323 - categorical_accuracy: 0.3571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.6862 - categorical_accuracy: 0.3750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 933ms/step - loss: 1.7370 - categorical_accuracy: 0.3889 - val_loss: 0.9083 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 19/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 0.8812 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 1.1046 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.8865 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 1.3041 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 1.2086 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 1.3478 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.6017 - categorical_accuracy: 0.4286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.6262 - categorical_accuracy: 0.3750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 868ms/step - loss: 1.6826 - categorical_accuracy: 0.3889 - val_loss: 3.2105 - val_categorical_accuracy: 0.0000e+00 - lr: 1.0000e-05
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 1.5559 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 4s - loss: 0.9237 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.7593 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 0.7952 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 0.8960 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 1.3237 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.2223 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.2323 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 7s 783ms/step - loss: 1.2676 - categorical_accuracy: 0.6111 - val_loss: 3.4308 - val_categorical_accuracy: 0.0000e+00 - lr: 1.0000e-05

# %%
plotModelHistory(model1_history)
# Out:
# Max. Training Accuracy 0.6728395223617554
# Max. Validaiton Accuracy 0.6666666865348816

# %% [markdown]
# ### Model 1.1 - Frames-16, Epoc-20, elu

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model2 = Sequential([
    Conv3D(16, make3dFilter(5), activation='elu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='elu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='elu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='elu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='elu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d1")
model2.compile(optimizer= tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model2.summary())

model2_history = model2.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_12 (Conv3D)          (None, 12, 96, 96, 16)    6016
#
#  max_pooling3d_12 (MaxPoolin  (None, 6, 48, 48, 16)    0
#  g3D)
#
#  batch_normalization_20 (Bat  (None, 6, 48, 48, 16)    64
#  chNormalization)
#
#  conv3d_13 (Conv3D)          (None, 4, 46, 46, 32)     13856
#
#  max_pooling3d_13 (MaxPoolin  (None, 4, 23, 23, 32)    0
#  g3D)
#
#  batch_normalization_21 (Bat  (None, 4, 23, 23, 32)    128
#  chNormalization)
#
#  conv3d_14 (Conv3D)          (None, 2, 21, 21, 64)     55360
#
#  max_pooling3d_14 (MaxPoolin  (None, 2,
- categorical_accuracy: 0.1667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 2.9820 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 2.5519 - categorical_accuracy: 0.3000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 2.1826 - categorical_accuracy: 0.4167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 2.5921 - categorical_accuracy: 0.3571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 2.5825 - categorical_accuracy: 0.3750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 851ms/step - loss: 2.4633 - categorical_accuracy: 0.3889 - val_loss: 1.7672 - val_categorical_accuracy: 0.1429 - lr: 1.0000e-06
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 5s - loss: 1.3731 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.9205 - categorical_accuracy: 0.5000    WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.9795 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 1.5453 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 2s - loss: 1.4493 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 1.2444 - categorical_accuracy: 0.5833WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.1232 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 1.3376 - categorical_accuracy: 0.5625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 7s 801ms/step - loss: 1.2418 - categorical_accuracy: 0.6111 - val_loss: 3.8430 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-06

# %%
plotModelHistory(model2_history)
# Out:
# Max. Training Accuracy 0.760869562625885
# Max. Validaiton Accuracy 0.6666666865348816

# %% [markdown]
# ### Model 2.0: Frames:16, Epocs-20, BS-64, relu >>> reduced kernel to (2,2,2), switching BatchNormalization before MaxPooling

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model3 = Sequential([
    Conv3D(16, make3dFilter(2), padding='same', activation='relu', input_shape=inputShape),
    BatchNormalization(),
    MaxPooling3D(make3dFilter(2)),

    Conv3D(32, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(64, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(128, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Flatten(),
    Dense(256, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.3),

    Dense(128, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_3d5")
model3.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model3.summary())

model3_history = model3.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_19 (Conv3D)          (None, 16, 100, 100, 16)  400
#
#  batch_normalization_29 (Bat  (None, 16, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_19 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_20 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  batch_normalization_30 (Bat  (None, 8, 50, 50, 32)    128
#  chNormalization)
#
#  max_pooling3d_20 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d_21 (Conv3D)          (None, 4, 25, 25, 64)     16448
#
#  batch_normalization_31 (Bat  (None, 4, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_21 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_22 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  batch_normalization_32 (Bat  (None, 2, 12, 12, 128)   512
#  chNormalization)
#
#  max_pooling3d_22 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_6 (Flatten)         (None, 4608)              0
#
#  dense_18 (Dense)            (None, 256)               1179904
#
#  dense_19 (Dense)            (None, 128)               32896
#
#  dense_20 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,301,045
# Trainable params: 1,300,565
# Non-trainable params: 480
# _________________________________________________________________
# None
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 3:02 - loss: 2.6731 - categorical_accuracy: 0.1875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2:35 - loss: 5.0764 - categorical_accuracy: 0.2109WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2:15 - loss: 6.1749 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1:52 - loss: 5.8366 - categorical_accuracy: 0.2305WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1:29 - loss: 5.5234 - categorical_accuracy: 0.2531WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1:06 - loss: 5.0947 - categorical_accuracy: 0.2708WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 43s - loss: 4.7129 - categorical_accuracy: 0.2723 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 21s - loss: 4.3552 - categorical_accuracy: 0.2930WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 4.2350 - categorical_accuracy: 0.3057 Source path =  ./Project_data/val ; batch size = 64
# 9/9 [==============================] - 199s 22s/step - loss: 4.2350 - categorical_accuracy: 0.3057 - val_loss: 1.5366 - val_categorical_accuracy: 0.2707 - lr: 0.0010
# Epoch 2/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 47s - loss: 1.4907 - categorical_accuracy: 0.3889WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 41s - loss: 2.0458 - categorical_accuracy: 0.2778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 35s - loss: 2.1449 - categorical_accuracy: 0.2963WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 29s - loss: 1.8229 - categorical_accuracy: 0.4028WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 23s - loss: 1.8621 - categorical_accuracy: 0.4111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 17s - loss: 1.8757 - categorical_accuracy: 0.4259WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 11s - loss: 1.8194 - categorical_accuracy: 0.4524WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 5s - loss: 2.0419 - categorical_accuracy: 0.4375 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 56s 6s/step - loss: 1.9381 - categorical_accuracy: 0.4630 - val_loss: 1.4917 - val_categorical_accuracy: 0.2667 - lr: 0.0010
# Epoch 3/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 47s - loss: 0.6866 - categorical_accuracy: 0.7778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 41s - loss: 0.8950 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 35s - loss: 1.3454 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 29s - loss: 1.1469 - categorical_accuracy: 0.6389WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA:
- val_categorical_accuracy: 0.1111 - lr: 1.0000e-05
# Epoch 12/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 21s - loss: 0.1798 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 19s - loss: 0.1597 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 16s - loss: 0.1800 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 13s - loss: 0.4042 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 11s - loss: 0.3525 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 8s - loss: 0.4011 - categorical_accuracy: 0.8750 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 4s - loss: 0.3967 - categorical_accuracy: 0.8800WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 2s - loss: 0.3890 - categorical_accuracy: 0.8846WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 20s 2s/step - loss: 0.3893 - categorical_accuracy: 0.8704 - val_loss: 14.5145 - val_categorical_accuracy: 0.1111 - lr: 1.0000e-06
# Epoch 13/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.0942 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.3265 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.3199 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 0.2504 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.2424 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.2962 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.3666 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4938 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 9s 965ms/step - loss: 0.5632 - categorical_accuracy: 0.7778 - val_loss: 14.0694 - val_categorical_accuracy: 0.1111 - lr: 1.0000e-06
# Epoch 14/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 1.0160 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.5816 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.5112 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 0.4114 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.5397 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.4543 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.4779 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4270 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 0.8249 - categorical_accuracy: 0.7222
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 9/9 [==============================] - 8s 963ms/step - loss: 0.8249 - categorical_accuracy: 0.7222 - val_loss: 14.6709 - val_categorical_accuracy: 0.1111 - lr: 1.0000e-06
# Epoch 15/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.2066 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.4942 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.6872 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 0.7029 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.5726 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.5285 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.4868 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4576 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 9s 976ms/step - loss: 0.4118 - categorical_accuracy: 0.8333 - val_loss: 8.7961 - val_categorical_accuracy: 0.1111 - lr: 1.0000e-07
# Epoch 16/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.2370 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.4637 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.7963 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 0.6359 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.5986 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.5955 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 1.0499 - categorical_accuracy: 0.5714WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.9202 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 9s 1s/step - loss: 1.0164 - categorical_accuracy: 0.6111 - val_loss: 16.0805 - val_categorical_accuracy: 0.1111 - lr: 1.0000e-07
# Epoch 17/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.7529 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.4306 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.3995 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 3s - loss: 0.3144 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.3008 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.4049 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.3577 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3217 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 0.3315 - categorical_accuracy: 0.8333
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 9/9 [==============================] - 9s 1s/step - loss: 0.3315 - categorical_accuracy: 0.8333 - val_loss: 27.5922 - val_categorical_accuracy: 0.0000e+00 - lr: 1.0000e-07
# Epoch 18/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 1.1920 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.6324 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.4894 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 4s - loss: 0.9802 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.8214 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.7388 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.6439 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5673 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 9s 1s/step - loss: 0.5152 - categorical_accuracy: 0.8889 - val_loss: 21.0726 - val_categorical_accuracy: 0.1111 - lr: 1.0000e-08
# Epoch 19/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.2666 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.9417 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.7772 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 4s - loss: 0.9189 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.7496 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.6258 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.5660 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.9653 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 911ms/step - loss: 0.8792 - categorical_accuracy: 0.6667 - val_loss: 21.1069 - val_categorical_accuracy: 0.1429 - lr: 1.0000e-08
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.3694 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.2673 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.4337 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 4s - loss: 0.5220 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.4418 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.4406 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.6277 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.5692 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 0.5239 - categorical_accuracy: 0.7222
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-09.
# 9/9 [==============================] - 8s 889ms/step - loss: 0.5239 - categorical_accuracy: 0.7222 - val_loss: 27.2820 - val_categorical_accuracy: 0.0000e+00 - lr: 1.0000e-08

# %%
plotModelHistory(model3_history)
# Out:
# Max. Training Accuracy 0.9027777910232544
# Max. Validaiton Accuracy 0.27067670226097107

# %% [markdown]
# ### Model 2.1: Frames:16, Epocs-20, BS-64, elu >>> reduced kernel to (2,2,2), switching BatchNormalization before MaxPooling

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model4 = Sequential([
    Conv3D(16, make3dFilter(2), padding='same', activation='elu', input_shape=inputShape),
    BatchNormalization(),
    MaxPooling3D(make3dFilter(2)),

    Conv3D(32, make3dFilter(2), padding='same', activation='elu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(64, make3dFilter(2), padding='same', activation='elu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(128, make3dFilter(2), padding='same', activation='elu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Flatten(),
    Dense(256, activation='elu'),
    # BatchNormalization(),
    # Dropout(0.3),

    Dense(128, activation='elu'),
    # BatchNormalization(),
    # Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_3d5")
model4.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model4.summary())

model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_23 (Conv3D)          (None, 16, 100, 100, 16)  400
#
#  batch_normalization_33 (Bat  (None, 16, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_23 (MaxPoolin  (None, 8, 50, 50, 16)    0
#  g3D)
#
#  conv3d_24 (Conv3D)          (None, 8, 50, 50, 32)     4128
#
#  batch_normalization_34 (Bat  (None, 8, 50, 50, 32)    128
#  chNormalization)
#
#  max_pooling3d_24 (MaxPoolin  (None, 4, 25, 25, 32)    0
#  g3D)
#
#  conv3d
# Epoch 18/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 1.0065 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 0.8213 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 4s - loss: 0.5721 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 4s - loss: 0.5192 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.4968 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.6915 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.6409 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.7156 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 0.6492 - categorical_accuracy: 0.7222
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-08.
# 9/9 [==============================] - 9s 1s/step - loss: 0.6492 - categorical_accuracy: 0.7222 - val_loss: 6.1927 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-07
# Epoch 19/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.2534 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 5s - loss: 1.2138 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 5s - loss: 0.8931 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 4s - loss: 0.6788 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.7089 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.6795 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.8246 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.7317 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 9s 1s/step - loss: 0.6740 - categorical_accuracy: 0.7222 - val_loss: 7.0206 - val_categorical_accuracy: 0.2857 - lr: 1.0000e-08
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 6s - loss: 0.2687 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 6s - loss: 1.1976 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 5s - loss: 0.9438 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 4s - loss: 0.8029 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 3s - loss: 0.7148 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 2s - loss: 0.6351 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 1s - loss: 0.6146 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.6262 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 8s 903ms/step - loss: 0.7015 - categorical_accuracy: 0.7778 - val_loss: 8.0840 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-08

# %%
plotModelHistory(model4_history)
# Out:
# Max. Training Accuracy 1.0
# Max. Validaiton Accuracy 0.5555555820465088

# %% [markdown]
# ### Model 3.0: Conv2D + LSTM, with relu

# %%
n_frames = 16
num_epochs = 30
batch_size = 32

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model5 = Sequential([
    TimeDistributed(Conv2D(16, make2dFilter(3), padding='same', activation='relu'), input_shape=inputShape),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(32, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(64, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(128, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(256, make2dFilter(3), padding='same', activation='relu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Flatten()),
    LSTM(256),
    Dropout(0.2),

    Dense(256, activation='relu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_2d_lstm")
model5.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model5.summary())

model5_history = model5.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_2d_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 16, 100, 100, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 16, 100, 100, 16)  64
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 16, 50, 50, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 16, 50, 50, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 16, 50, 50, 32)   128
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 16, 25, 25, 32)   0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 16, 25, 25, 64)   18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 16, 25, 25, 64)   256
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 16, 12, 12, 64)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 16, 12, 12, 128)  73856
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 16, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 16, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 16, 6, 6, 256)    295168
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 16, 6, 6, 256)    1024
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 16, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 16, 2304)         0
#  stributed)
#
#  lstm (LSTM)                 (None, 256)               2622464
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_24 (Dense)            (None, 256)               65792
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_25 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,084,133
# Trainable params: 3,083,141
# Non-trainable params: 992
# _________________________________________________________________
# None
# Source path =  ./Project_data/train ; batch size = 32
# Epoch 1/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 1:17 - loss: 1.7074 - categorical_accuracy: 0.2188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 1:22 - loss: 1.6775 - categorical_accuracy: 0.2656WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 1:16 - loss: 1.6604 - categorical_accuracy: 0.2396WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 1:10 - loss: 1.6684 - categorical_accuracy: 0.2344WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 1:06 - loss: 1.6357 - categorical_accuracy: 0.2688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 1:00 - loss: 1.5828 - categorical_accuracy: 0.2969WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 55s - loss: 1.5169 - categorical_accuracy: 0.3482 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 50s - loss: 1.4896 - categorical_accuracy: 0.3555WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 44s - loss: 1.4805 - categorical_accuracy: 0.3542WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 39s - loss: 1.4507 - categorical_accuracy: 0.3719WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 33s - loss: 1.4222 - categorical_accuracy: 0.3920WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 28s - loss: 1.3988 - categorical_accuracy: 0.4062WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 22s - loss: 1.3750 - categorical_accuracy: 0.4159WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 16s - loss: 1.3567 - categorical_accuracy: 0.4241WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 11s - loss: 1.3522 - categorical_accuracy: 0.4208WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 5s - loss: 1.3372 - categorical_accuracy: 0.4355 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 1.3306 - categorical_accuracy: 0.4396Source path =  ./Project_data/val ; batch size = 32
# 17/17 [==============================] - 112s 7s/step - loss: 1.3306 - categorical_accuracy: 0.4396 - val_loss: 1.5910 - val_categorical_accuracy: 0.2256 - lr: 0.0010
# Epoch 2/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 26s - loss: 0.9775 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 52s - loss: 0.9741 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA:
- categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 1.3805 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 1.3007 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 1.2561 - categorical_accuracy: 0.3750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 1.0268 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.9318 - categorical_accuracy: 0.5833WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 1.0310 - categorical_accuracy: 0.5714WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 1.0295 - categorical_accuracy: 0.5625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 1.0141 - categorical_accuracy: 0.5556WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 1.1180 - categorical_accuracy: 0.5500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 1.0635 - categorical_accuracy: 0.5909WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.9996 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 1.1394 - categorical_accuracy: 0.6154WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 1.0762 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 1.0375 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 1.0374 - categorical_accuracy: 0.6562WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 9s 543ms/step - loss: 1.0590 - categorical_accuracy: 0.6471 - val_loss: 2.9953 - val_categorical_accuracy: 0.1333 - lr: 1.0000e-06
# Epoch 13/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.1805 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 0.4366 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.6448 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.6150 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.5838 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.6230 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.7528 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.6864 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6233 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 3s - loss: 0.6619 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.7219 - categorical_accuracy: 0.7273WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.7396 - categorical_accuracy: 0.7083WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.7627 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.7845 - categorical_accuracy: 0.6786WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.7961 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7655 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 0.7422 - categorical_accuracy: 0.7059
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 17/17 [==============================] - 9s 574ms/step - loss: 0.7422 - categorical_accuracy: 0.7059 - val_loss: 2.1591 - val_categorical_accuracy: 0.3846 - lr: 1.0000e-06
# Epoch 14/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.3919 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 0.4991 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.8053 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.6493 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 0.6499 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.6486 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.6176 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.5576 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6334 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.6249 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.6509 - categorical_accuracy: 0.6818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.6833 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.6486 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.6661 - categorical_accuracy: 0.6786WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6415 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6435 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 475ms/step - loss: 0.7131 - categorical_accuracy: 0.6765 - val_loss: 2.7189 - val_categorical_accuracy: 0.0000e+00 - lr: 1.0000e-07
# Epoch 15/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 1.2209 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6549 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 488ms/step - loss: 0.7534 - categorical_accuracy: 0.8529 - val_loss: 1.4662 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-09
# Epoch 26/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.5976 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 0.9362 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.6714 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.5647 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 0.4813 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.5932 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.5553 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.5465 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.5655 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.5423 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.5427 - categorical_accuracy: 0.7273WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.5460 - categorical_accuracy: 0.7083WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.5781 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.5476 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.5261 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.5310 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 0.5292 - categorical_accuracy: 0.7647
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-10.
# 17/17 [==============================] - 8s 487ms/step - loss: 0.5292 - categorical_accuracy: 0.7647 - val_loss: 1.2750 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-09
# Epoch 27/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 2.1215 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 1.2277 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.9610 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.9552 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.7822 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.6696 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.6547 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.7411 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6952 - categorical_accuracy: 0.7778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 3s - loss: 0.7337 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.7740 - categorical_accuracy: 0.7273WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.7569 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.7181 - categorical_accuracy: 0.7692WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.7423 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.7520 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7927 - categorical_accuracy: 0.7188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 475ms/step - loss: 0.7736 - categorical_accuracy: 0.7353 - val_loss: 2.6724 - val_categorical_accuracy: 0.2000 - lr: 1.0000e-10
# Epoch 28/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.9712 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 7s - loss: 0.8971 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.7913 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.7373 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 0.7625 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.8292 - categorical_accuracy: 0.5833WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 3s - loss: 0.7279 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.8535 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.8310 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.8152 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.7576 - categorical_accuracy: 0.6364WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.8324 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.8577 - categorical_accuracy: 0.6154WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.8273 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.8138 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7733 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 467ms/step - loss: 0.8154 - categorical_accuracy: 0.6765 - val_loss: 1.6513 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-10
# Epoch 29/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.1089 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 0.4652 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 4s - loss: 0.6425 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 4s - loss: 0.8350 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 0.7031 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.6617 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 3s - loss: 0.5963 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.5885 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.5492 - categorical_accuracy: 0.8889WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.5688 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.5956 - categorical_accuracy: 0.8636WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 1s - loss: 0.6350 - categorical_accuracy: 0.7917WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.7042 - categorical_accuracy: 0.7308WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.6705 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6538 - categorical_accuracy: 0.7667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6939 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 0.6883 - categorical_accuracy: 0.7647
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 17/17 [==============================] - 8s 462ms/step - loss: 0.6883 - categorical_accuracy: 0.7647 - val_loss: 0.9398 - val_categorical_accuracy: 0.6000 - lr: 1.0000e-10
# Epoch 30/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.6293 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 6s - loss: 0.5202 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 1.0819 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.8789 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 0.9103 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 1.1013 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 3s - loss: 1.0855 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.9946 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.9656 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.9727 - categorical_accuracy: 0.6500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.9130 - categorical_accuracy: 0.6818WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.9348 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.9299 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.8934 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.8625 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.8136 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 457ms/step - loss: 0.8055 - categorical_accuracy: 0.7353 - val_loss: 0.5531 - val_categorical_accuracy: 0.8000 - lr: 1.0000e-11

# %%
plotModelHistory(model5_history)
# Out:
# Max. Training Accuracy 0.8529411554336548
# Max. Validaiton Accuracy 0.800000011920929

# %% [markdown]
# ### Model 3.1: Conv2D + LSTM, with elu

# %%
n_frames = 16
num_epochs = 30
batch_size = 32

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model6 = Sequential([
    TimeDistributed(Conv2D(16, make2dFilter(3), padding='same', activation='elu'), input_shape=inputShape),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(32, make2dFilter(3), padding='same', activation='elu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(64, make2dFilter(3), padding='same', activation='elu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(128, make2dFilter(3), padding='same', activation='elu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Conv2D(256, make2dFilter(3), padding='same', activation='elu')),
    TimeDistributed(BatchNormalization()),
    TimeDistributed(MaxPooling2D(make2dFilter(2))),

    TimeDistributed(Flatten()),
    LSTM(256),
    Dropout(0.2),

    Dense(256, activation='elu'),
    Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_2d_lstm")
model6.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model6.summary())

model6_history = model6.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_2d_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_16 (TimeDi  (None, 16, 100, 100, 16)  448
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 16, 100, 100, 16)  64
#  stributed)
#
#  time_distributed_18 (TimeDi  (None, 16, 50, 50, 16)   0
#  stributed)
#
#  time_distributed_19 (TimeDi  (None, 16, 50, 50, 32)   4640
#  stributed)
#
#  time_distributed_20 (TimeDi  (None, 16, 50, 50, 32)   128
#  stributed)
#
#  time_distributed_21 (TimeDi  (None, 16, 25, 25, 32)   0
#  stributed)
#
#  time_distributed_22 (TimeDi  (None, 16, 25, 25, 64)   18496
#  stributed)
#
#  time_distributed_23 (TimeDi  (None, 16, 25, 25, 64)   256
#  stributed)
#
#  time_distributed_24 (TimeDi  (None, 16, 12, 12, 64)   0
#  stributed)
#
#  time_distributed_25 (TimeDi  (None, 16, 12, 12, 128)  73856
#  stributed)
#
#  time_distributed_26 (TimeDi  (None, 16, 12, 12, 128)  512
#  stributed)
#
#  time_distributed_27 (TimeDi  (None, 16, 6, 6, 128)    0
#  stributed)
#
#  time_distributed_28 (TimeDi  (None, 16, 6, 6, 256)    295168
#  stributed)
#
#  time_distributed_29 (TimeDi  (None, 16, 6, 6, 256)    1024
#  stributed)
#
#  time_distributed_30 (TimeDi  (None, 16, 3, 3, 256)    0
#  stributed)
#
#  time_distributed_31 (TimeDi  (None, 16, 2304)         0
#  stributed)
#
#  lstm_1 (LSTM)               (None, 256)               2622464
#
#  dropout_12 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 256)               65792
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_27 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 3,084,133
# Trainable params: 3,083,141
# Non-trainable params: 992
# _________________________________________________________________
# None
# Source path =  ./Project_data/train ; batch size = 32
# Epoch 1/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 1:31 - loss: 1.6750 - categorical_accuracy: 0.2188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 1:21 - loss: 2.1769 - categorical_accuracy: 0.2188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 1:16 - loss: 1.9679 - categorical_accuracy: 0.2604WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 1:11 - loss: 1.8711 - categorical_accuracy: 0.3125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 1:06 - loss: 1.8707 - categorical_accuracy: 0.3375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 1:01 - loss: 1.7635 - categorical_accuracy: 0.3802WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 55s - loss: 1.7281 - categorical_accuracy: 0.3616 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 50s - loss: 1.6641 - categorical_accuracy: 0.3750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 44s - loss: 1.5985 - categorical_accuracy: 0.3958WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 38s - loss: 1.5653 - categorical_accuracy: 0.4031WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 33s - loss: 1.5356 - categorical_accuracy: 0.4062WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 27s - loss: 1.5233 - categorical_accuracy: 0.4089WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 22s - loss: 1.5204 - categorical_accuracy: 0.4014WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 16s - loss: 1.4909 - categorical_accuracy: 0.4129WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 11s - loss: 1.4705 - categorical_accuracy: 0.4229WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 5s - loss: 1.4516 - categorical_accuracy: 0.4297 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 1.4294 - categorical_accuracy: 0.4377Source path =  ./Project_data/val ; batch size = 32
# 17/17 [==============================] - 111s 7s/step - loss: 1.4294 - categorical_accuracy: 0.4377 - val_loss: 1.7084 - val_categorical_accuracy: 0.2632 - lr: 0.0010
# Epoch 2/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA:
- categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.7220 - categorical_accuracy: 0.5833WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.6687 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.6854 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6241 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.7379 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.7224 - categorical_accuracy: 0.6364WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 1s - loss: 0.6772 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.6418 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.6045 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.5764 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7060 - categorical_accuracy: 0.7188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 0.6997 - categorical_accuracy: 0.7353
# Epoch 10: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 17/17 [==============================] - 9s 548ms/step - loss: 0.6997 - categorical_accuracy: 0.7353 - val_loss: 5.2605 - val_categorical_accuracy: 0.0667 - lr: 1.0000e-05
# Epoch 11/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.0642 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 7s - loss: 0.4488 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 6s - loss: 1.1476 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 1.6645 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 1.3857 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 1.3182 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 1.4347 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 1.2728 - categorical_accuracy: 0.5625WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 1.1482 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 1.0715 - categorical_accuracy: 0.6500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 1.1803 - categorical_accuracy: 0.6364WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 1.1240 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 1.0637 - categorical_accuracy: 0.6538WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 1.0271 - categorical_accuracy: 0.6786WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 1.0386 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.9894 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 9s 550ms/step - loss: 0.9655 - categorical_accuracy: 0.6765 - val_loss: 3.5254 - val_categorical_accuracy: 0.2667 - lr: 1.0000e-06
# Epoch 12/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 1.6411 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 1.2005 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 1.2243 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 1.1311 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 1.0063 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 1.0396 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.9333 - categorical_accuracy: 0.5714WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.8557 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.8851 - categorical_accuracy: 0.6111WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.8757 - categorical_accuracy: 0.6500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.8893 - categorical_accuracy: 0.6364WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.8218 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.7933 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.7630 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.7199 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7408 - categorical_accuracy: 0.7188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 9s 568ms/step - loss: 0.7429 - categorical_accuracy: 0.7059 - val_loss: 3.4758 - val_categorical_accuracy: 0.3333 - lr: 1.0000e-06
# Epoch 13/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.7118 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 6s - loss: 0.7060 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 6s - loss: 0.5882 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 6s - loss: 0.6394 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.5411 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.6570 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.6185 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.6071 - categorical_accuracy: 0.8125WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6517 - categorical_accuracy: 0.7778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.6202 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.6046 - categorical_accuracy: 0.8182WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.6910 - categorical_accuracy: 0.7917WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.6561 - categorical_accuracy: 0.8077WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.7173 - categorical_accuracy: 0.7857WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.7550 - categorical_accuracy: 0.7667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7530 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 0.7812 - categorical_accuracy: 0.7353
# Epoch 13: ReduceLROnPlateau reducing learning rate to 1.0000001111620805e-07.
# 17/17 [==============================] - 9s 541ms/step - loss: 0.7812 - categorical_accuracy: 0.7353 - val_loss: 4.0831 - val_categorical_accuracy: 0.2308 - lr: 1.0000e-06
# Epoch 14/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 1.6538 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 1.0671 - categorical_accuracy: 0.5000    WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.9526 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.7509 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.8052 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.7313 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.7267 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.7225 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6769 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.6740 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.6443 - categorical_accuracy: 0.7273WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.6008 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.5926 - categorical_accuracy: 0.7692WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.6767 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6882 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6831 - categorical_accuracy: 0.7188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 461ms/step - loss: 0.6779 - categorical_accuracy: 0.7059 - val_loss: 6.1831 - val_categorical_accuracy: 0.0000e+00 - lr: 1.0000e-07
# Epoch 15/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.1549 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# ...
# 15/17 [=========================>....] - ETA: 0s - loss: 0.5951 - categorical_accuracy: 0.7667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.6168 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 457ms/step - loss: 0.6485 - categorical_accuracy: 0.7353 - val_loss: 2.4996 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-10
# Epoch 26/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.9121 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 5s - loss: 0.9037 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 6s - loss: 0.6450 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 6s - loss: 0.9438 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.8297 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 5s - loss: 0.8421 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 1.0240 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.9198 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.9623 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.8928 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.8528 - categorical_accuracy: 0.7273WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.9613 - categorical_accuracy: 0.7083WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.9599 - categorical_accuracy: 0.6923WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.9200 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.9350 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 1.0014 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 499ms/step - loss: 0.9647 - categorical_accuracy: 0.7059 - val_loss: 1.1877 - val_categorical_accuracy: 0.6000 - lr: 1.0000e-10
# Epoch 27/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.2261 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 7s - loss: 1.1485 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 6s - loss: 1.0510 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 1.0731 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 4s - loss: 0.9392 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.8632 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 3s - loss: 1.1275 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 1.2546 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 1.1418 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 1.1355 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 1.1370 - categorical_accuracy: 0.5909WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 1s - loss: 1.0571 - categorical_accuracy: 0.6250WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 1.0207 - categorical_accuracy: 0.6538WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.9708 - categorical_accuracy: 0.6786WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.9345 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 1.0006 - categorical_accuracy: 0.6562WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 477ms/step - loss: 0.9718 - categorical_accuracy: 0.6765 - val_loss: 2.6907 - val_categorical_accuracy: 0.2000 - lr: 1.0000e-10
# Epoch 28/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.0987 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 7s - loss: 0.2074 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 6s - loss: 0.3478 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.4504 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.5600 - categorical_accuracy: 0.7000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.7546 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.8263 - categorical_accuracy: 0.6429WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 3s - loss: 0.7551 - categorical_accuracy: 0.6875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.6926 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 2s - loss: 0.6660 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.6284 - categorical_accuracy: 0.7727WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.6281 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.6304 - categorical_accuracy: 0.7308WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.6126 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.6470 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.7337 - categorical_accuracy: 0.7188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 467ms/step - loss: 0.7176 - categorical_accuracy: 0.7059 - val_loss: 1.5356 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-10
# Epoch 29/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 1.3839 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 6s - loss: 1.6391 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 6s - loss: 1.2692 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 6s - loss: 1.2908 - categorical_accuracy: 0.5000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 1.0853 - categorical_accuracy: 0.6000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 5s - loss: 0.9644 - categorical_accuracy: 0.6667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.8681 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 4s - loss: 0.8133 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.8634 - categorical_accuracy: 0.7222WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 3s - loss: 0.8030 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.7473 - categorical_accuracy: 0.7727WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.7448 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.7079 - categorical_accuracy: 0.7692WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.7683 - categorical_accuracy: 0.7143WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.7569 - categorical_accuracy: 0.7333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.8410 - categorical_accuracy: 0.7188WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - ETA: 0s - loss: 0.8493 - categorical_accuracy: 0.7059
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.000000082740371e-11.
# 17/17 [==============================] - 8s 461ms/step - loss: 0.8493 - categorical_accuracy: 0.7059 - val_loss: 2.5999 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-10
# Epoch 30/30
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  1/17 [>.............................] - ETA: 4s - loss: 0.4547 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  2/17 [==>...........................] - ETA: 7s - loss: 0.3382 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  3/17 [====>.........................] - ETA: 5s - loss: 0.4073 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  4/17 [======>.......................] - ETA: 5s - loss: 0.3632 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  5/17 [=======>......................] - ETA: 5s - loss: 0.4095 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  6/17 [=========>....................] - ETA: 4s - loss: 0.4413 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  7/17 [===========>..................] - ETA: 4s - loss: 0.4603 - categorical_accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  8/17 [=============>................] - ETA: 4s - loss: 0.4123 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
#  9/17 [==============>...............] - ETA: 3s - loss: 0.4264 - categorical_accuracy: 0.9444WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 10/17 [================>.............] - ETA: 3s - loss: 0.5139 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 11/17 [==================>...........] - ETA: 2s - loss: 0.4947 - categorical_accuracy: 0.9091WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 12/17 [====================>.........] - ETA: 2s - loss: 0.4980 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 13/17 [=====================>........] - ETA: 1s - loss: 0.4691 - categorical_accuracy: 0.9231WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 14/17 [=======================>......] - ETA: 1s - loss: 0.4883 - categorical_accuracy: 0.8929WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 15/17 [=========================>....] - ETA: 0s - loss: 0.4705 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 16/17 [===========================>..] - ETA: 0s - loss: 0.4527 - categorical_accuracy: 0.9062WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 17/17 [==============================] - 8s 494ms/step - loss: 0.4414 - categorical_accuracy: 0.9118 - val_loss: 2.4389 - val_categorical_accuracy: 0.4000 - lr: 1.0000e-11

# %%
plotModelHistory(model6_history)
# Out:
# Max. Training Accuracy 0.9117646813392639
# Max. Validaiton Accuracy 0.6000000238418579

# %% [markdown]
# ### Model 4.0: Transfer Learning (MobileNet) with LSTM, relu

# %%
from tensorflow.keras.applications import mobilenet

# %%
mobilenet = mobilenet.MobileNet(weights='imagenet', include_top=False)

n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model7 = Sequential([
    TimeDistributed(mobilenet, input_shape=inputShape)
], name="mobilenet_lstm")

for layer in model7.layers:
    layer.trainable = False

model7.add(TimeDistributed(BatchNormalization()))
model7.add(TimeDistributed(MaxPooling2D(make2dFilter(2))))
model7.add(TimeDistributed(Flatten()))

model7.add(LSTM(256))
model7.add(Dropout(0.2))

model7.add(Dense(256,activation='relu'))
model7.add(Dropout(0.2))

model7.add(Dense(5, activation='softmax'))

model7.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model7.summary())

model7_history = model7.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenet_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_32 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_33 (TimeDi  (None, 20, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_34 (TimeDi  (None, 20, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_35 (TimeDi  (None, 20, 1024)         0
#  stributed)
#
#  lstm_2 (LSTM)               (None, 256)               1311744
#
#  dropout_14 (Dropout)        (None, 256)               0
#
#  dense_28 (Dense)            (None, 256)               65792
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_29 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 4,611,781
# Trainable params: 1,380,869
# Non-trainable params: 3,230,912
# _________________________________________________________________
# None
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 48s - loss: 1.6282 - categorical_accuracy: 0.2344WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 1:22 - loss: 1.6420 - categorical_accuracy: 0.2344WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 1:09 - loss: 1.5955 - categorical_accuracy: 0.2500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 58s - loss: 1.5559 - categorical_accuracy: 0.2969 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 46s - loss: 1.5233 - categorical_accuracy: 0.3187WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 34s - loss: 1.4782 - categorical_accuracy: 0.3568WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 23s - loss: 1.4277 - categorical_accuracy: 0.3862WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 11s - loss: 1.3789 - categorical_accuracy: 0.4141WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 1.3516 - categorical_accuracy: 0.4340 Source path =  ./Project_data/val ; batch size = 64
# 9/9 [==============================] - 117s 14s/step - loss: 1.3516 - categorical_accuracy: 0.4340 - val_loss: 1.0822 - val_categorical_accuracy: 0.6165 - lr: 0.0010
# Epoch 2/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 7s - loss: 0.7064 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 19s - loss: 0.7540 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 17s - loss: 0.6897 - categorical_accuracy: 0.8148WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 16s - loss: 0.6529 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 12s - loss: 0.6512 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 9s - loss: 0.6518 - categorical_accuracy: 0.8241 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 6s - loss: 0.6243 - categorical_accuracy: 0.8413WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 3s - loss: 0.6330 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 31s 4s/step - loss: 0.6050 - categorical_accuracy: 0.8457 - val_loss: 0.8958 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 3/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 7s - loss: 0.4310 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 20s - loss: 0.4813 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 18s - loss: 0.4416 - categorical_accuracy: 0.8519WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 14s - loss: 0.4311 - categorical_accuracy: 0.8611WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 12s - loss: 0.4339 - categorical_accuracy: 0.8556WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 9s - loss: 0.4167 - categorical_accuracy: 0.8519 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 6s - loss: 0.4127 - categorical_accuracy: 0.8651WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 3s - loss: 0.4091 - categorical_accuracy: 0.8611WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 30s 4s/step - loss: 0.3953 - categorical_accuracy: 0.8642 - val_loss: 1.2592 - val_categorical_accuracy: 0.6000 - lr: 0.0010
# Epoch 4/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 7s - loss: 0.4210 - categorical_accuracy: 0.8889WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 23s - loss: 0.4575 - categorical_accuracy: 0.8611WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 19s - loss: 0.4911 - categorical_accuracy: 0.8519WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 17s - loss: 0.5022 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 13s - loss: 0.4543 - categorical_accuracy: 0.8556WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 9s - loss: 0.4899 - categorical_accuracy: 0.8241 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 6s - loss: 0.5112 - categorical_accuracy: 0.8095WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 3s - loss: 0.5058 - categorical_accuracy: 0.8056WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 30s 4s/step - loss: 0.4899 - categorical_accuracy: 0.8148 - val_loss: 0.8741 - val_categorical_accuracy: 0.6667 - lr: 0.0010
# Epoch 5/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 7s - loss: 0.5899 - categorical_accuracy: 0.7778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 22s - loss: 0.6288 - categorical_accuracy: 0.7778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 13s - loss: 0.5411 - categorical_accuracy: 0.7955WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 10s - loss: 0.4789 - categorical_accuracy: 0.8269WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA:
- categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.6002 - categorical_accuracy: 0.8000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.5011 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.4894 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.4314 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 5s 591ms/step - loss: 0.3847 - categorical_accuracy: 0.8889 - val_loss: 0.3540 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-06
# Epoch 19/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0428 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 3s - loss: 0.4191 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2s - loss: 0.2844 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 2s - loss: 0.2383 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.1932 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.1664 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1556 - categorical_accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1364 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 5s 560ms/step - loss: 0.1277 - categorical_accuracy: 0.9444 - val_loss: 0.1778 - val_categorical_accuracy: 0.8571 - lr: 1.0000e-06
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.3047 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2s - loss: 0.1896 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2s - loss: 0.1408 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1s - loss: 0.1135 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.0949 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.0903 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0825 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.0845 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 4s 440ms/step - loss: 0.0821 - categorical_accuracy: 1.0000 - val_loss: 0.8621 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-06

# %%
plotModelHistory(model7_history)
# Out:
# Max. Training Accuracy 1.0
# Max. Validaiton Accuracy 0.8888888955116272

# %% [markdown]
# ### Model 4.1: Transfer Learning (MobileNet) with LSTM, elu

# %%
mobilenet = tf.keras.applications.mobilenet.MobileNet(weights='imagenet', include_top=False)

n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model8 = Sequential([
    TimeDistributed(mobilenet, input_shape=inputShape)
], name="mobilenet_lstm")

for layer in model8.layers:
    layer.trainable = False

model8.add(TimeDistributed(BatchNormalization()))
model8.add(TimeDistributed(MaxPooling2D(make2dFilter(2))))
model8.add(TimeDistributed(Flatten()))

model8.add(LSTM(256))
model8.add(Dropout(0.2))

model8.add(Dense(256,activation='elu'))
model8.add(Dropout(0.2))

model8.add(Dense(5, activation='softmax'))

model8.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model8.summary())

model8_history = model8.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "mobilenet_lstm"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_36 (TimeDi  (None, 20, 3, 3, 1024)   3228864
#  stributed)
#
#  time_distributed_37 (TimeDi  (None, 20, 3, 3, 1024)   4096
#  stributed)
#
#  time_distributed_38 (TimeDi  (None, 20, 1, 1, 1024)   0
#  stributed)
#
#  time_distributed_39 (TimeDi  (None, 20, 1024)         0
#  stributed)
#
#  lstm_3 (LSTM)               (None, 256)               1311744
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_30 (Dense)            (None, 256)               65792
#
#  dropout_17 (Dropout)        (None, 256)               0
#
#  dense_31 (Dense)            (None, 5)                 1285
#
# =================================================================
# Total params: 4,611,781
# Trainable params: 1,380,869
# Non-trainable params: 3,230,912
# _________________________________________________________________
# None
# Source path =  ./Project_data/train ; batch size = 64
# Epoch 1/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 46s - loss: 1.7880 - categorical_accuracy: 0.1562WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 1:10 - loss: 1.7237 - categorical_accuracy: 0.1953WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 1:03 - loss: 1.6134 - categorical_accuracy: 0.2812WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 53s - loss: 1.5149 - categorical_accuracy: 0.3398 WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 43s - loss: 1.4359 - categorical_accuracy: 0.3875WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 33s - loss: 1.3801 - categorical_accuracy: 0.4219WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 22s - loss: 1.3291 - categorical_accuracy: 0.4464WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 11s - loss: 1.2918 - categorical_accuracy: 0.4609WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 1.2652 - categorical_accuracy: 0.4736 Source path =  ./Project_data/val ; batch size = 64
# 9/9 [==============================] - 114s 13s/step - loss: 1.2652 - categorical_accuracy: 0.4736 - val_loss: 1.2421 - val_categorical_accuracy: 0.4812 - lr: 0.0010
# Epoch 2/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 7s - loss: 0.5229 - categorical_accuracy: 0.7778WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 23s - loss: 0.4567 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 20s - loss: 0.4429 - categorical_accuracy: 0.8704WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 16s - loss: 0.4419 - categorical_accuracy: 0.8611WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 13s - loss: 0.4319 - categorical_accuracy: 0.8667WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 9s - loss: 0
WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 14s 2s/step - loss: 0.1040 - categorical_accuracy: 0.9583 - val_loss: 0.9713 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 11/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 3s - loss: 0.3039 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 9s - loss: 0.2272 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 9s - loss: 0.1891 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 7s - loss: 0.1607 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 5s - loss: 0.1323 - categorical_accuracy: 0.9500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 4s - loss: 0.1182 - categorical_accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 2s - loss: 0.1042 - categorical_accuracy: 0.9643WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 1s - loss: 0.0994 - categorical_accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 14s 2s/step - loss: 0.0950 - categorical_accuracy: 0.9722 - val_loss: 0.2838 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 12/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 3s - loss: 0.0403 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 8s - loss: 0.0820 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 6s - loss: 0.0699 - categorical_accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 6s - loss: 0.0609 - categorical_accuracy: 0.9688WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 5s - loss: 0.0580 - categorical_accuracy: 0.9750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 3s - loss: 0.0806 - categorical_accuracy: 0.9583WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 2s - loss: 0.0783 - categorical_accuracy: 0.9600WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 1s - loss: 0.1028 - categorical_accuracy: 0.9423WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 10s 1s/step - loss: 0.0997 - categorical_accuracy: 0.9444 - val_loss: 0.4113 - val_categorical_accuracy: 0.8889 - lr: 1.0000e-04
# Epoch 13/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0658 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 3s - loss: 0.0439 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2s - loss: 0.0310 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1s - loss: 0.0770 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.1021 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.0856 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.0807 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.0796 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 6s 684ms/step - loss: 0.0765 - categorical_accuracy: 1.0000 - val_loss: 0.8076 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 14/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.1490 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 3s - loss: 0.1460 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 3s - loss: 0.1016 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 2s - loss: 0.1056 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.1079 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.2598 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.2435 - categorical_accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.2137 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 0.1916 - categorical_accuracy: 0.9444
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 9/9 [==============================] - 6s 669ms/step - loss: 0.1916 - categorical_accuracy: 0.9444 - val_loss: 0.6185 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-04
# Epoch 15/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0043 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2s - loss: 0.0215 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2s - loss: 0.0575 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1s - loss: 0.0468 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.3419 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.3274 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.4019 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3894 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 5s 600ms/step - loss: 0.3787 - categorical_accuracy: 0.8889 - val_loss: 0.5248 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-05
# Epoch 16/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.1649 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2s - loss: 0.2267 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 1s - loss: 0.2263 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1s - loss: 0.1749 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.2304 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 0s - loss: 0.3345 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.3001 - categorical_accuracy: 0.8571WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3238 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 5s 587ms/step - loss: 0.2909 - categorical_accuracy: 0.8889 - val_loss: 0.4689 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-05
# Epoch 17/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0015 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 3s - loss: 0.3452 - categorical_accuracy: 0.7500WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2s - loss: 0.2633 - categorical_accuracy: 0.8333WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 2s - loss: 0.2340 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.1876 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.1645 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1414 - categorical_accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1291 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - ETA: 0s - loss: 0.1675 - categorical_accuracy: 0.9444
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.0000000656873453e-06.
# 9/9 [==============================] - 5s 627ms/step - loss: 0.1675 - categorical_accuracy: 0.9444 - val_loss: 0.8985 - val_categorical_accuracy: 0.6667 - lr: 1.0000e-05
# Epoch 18/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0452 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 3s - loss: 0.1641 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 2s - loss: 0.1504 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 2s - loss: 0.7186 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.6133 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.5111 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.4395 - categorical_accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.3865 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 5s 660ms/step - loss: 0.4372 - categorical_accuracy: 0.8889 - val_loss: 0.9357 - val_categorical_accuracy: 0.7778 - lr: 1.0000e-06
# Epoch 19/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.0011 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 4s - loss: 0.1436 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 3s - loss: 0.1219 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 2s - loss: 0.1149 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.1049 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.1318 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1186 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1052 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 5s 577ms/step - loss: 0.1256 - categorical_accuracy: 1.0000 - val_loss: 0.5893 - val_categorical_accuracy: 0.7143 - lr: 1.0000e-06
# Epoch 20/20
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 1/9 [==>...........................] - ETA: 1s - loss: 0.2355 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 2/9 [=====>........................] - ETA: 2s - loss: 0.1445 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 3/9 [=========>....................] - ETA: 1s - loss: 0.1060 - categorical_accuracy: 1.0000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4/9 [============>.................] - ETA: 1s - loss: 0.2666 - categorical_accuracy: 0.8750WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 5/9 [===============>..............] - ETA: 1s - loss: 0.2488 - categorical_accuracy: 0.9000WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 6/9 [===================>..........] - ETA: 1s - loss: 0.2264 - categorical_accuracy: 0.9167WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 7/9 [======================>.......] - ETA: 0s - loss: 0.1952 - categorical_accuracy: 0.9286WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 8/9 [=========================>....] - ETA: 0s - loss: 0.1721 - categorical_accuracy: 0.9375WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 9/9 [==============================] - 4s 468ms/step - loss: 0.1530 - categorical_accuracy: 0.9444 - val_loss: 0.1879 - val_categorical_accuracy: 1.0000 - lr: 1.0000e-06

# %%
plotModelHistory(model8_history)
# Out:
# Max. Training Accuracy 1.0
# Max. Validaiton Accuracy 1.0

# %% [markdown]
# ## Model Prediction _ Best Model

# %% [markdown]
# @jiayu and Andrew need to test the best model, with accuracy metrics + confusion matrix
